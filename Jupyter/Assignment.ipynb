# %%
import numpy as np
import matplotlib.pyplot as plt

# Hadoop vs Spark for Carrier Delay

# Inserting inputs manually
x = ["1", "2", "3", "4", "5"]
hadoop_y = [20.739,
7.467,
8.023,
7.067,
7.548
]
spark_y = [8.987,
8.926,
0.826,
0.686,
9.06
]


# Create the double bar graph
plt.bar(r1, hadoop_y, color='green', width=barWidth, label='Hadoop')
plt.bar(r2, spark_y, color='orange', width=barWidth, label='Spark')

# Add labels and title
plt.xlabel("Number of iterations")
plt.ylabel("Running Time (s)")
plt.title("Hadoop vs Spark for Carrier Delay")


# legend
plt.legend()

# Show the graph
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Hadoop vs Spark for Nas Delay

# Inserting inputs manually
x = ["1", "2", "3", "4", "5"]
hadoop_y = [14.974,
7.925,
7.597,
7.663,
7.185
]
spark_y = [9.017,
0.72,
0.65,
0.67,
0.56

]


# Create the double bar graph
plt.bar(r1, hadoop_y, color='green', width=barWidth, label='Hadoop')
plt.bar(r2, spark_y, color='orange', width=barWidth, label='Spark')

# Add labels and title
plt.xlabel("Number of iterations")
plt.ylabel("Running Time (s)")
plt.title("Hadoop vs Spark for Nas Delay")


# legend
plt.legend()

# Show the graph
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#Hadoop vs Spark for Weather Delay

# Inserting inputs manually
x = ["1", "2", "3", "4", "5"]
hadoop_y = [12.267,
7.576,
7.865,
7.483,
7.031
]
spark_y = [8.765,
8.374,
8.946,
0.652,
0.664
]


# Create the double bar graph
plt.bar(r1, hadoop_y, color='green', width=barWidth, label='Hadoop')
plt.bar(r2, spark_y, color='orange', width=barWidth, label='Spark')

# Add labels and title
plt.xlabel("Number of iterations")
plt.ylabel("Running Time (s)")
plt.title("Hadoop vs Spark for Weather Delay")


# legend
plt.legend()

# Show the graph
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#Hadoop vs Spark for LateAircraft Delay


# Inserting inputs manually
x = ["1", "2", "3", "4", "5"]
hadoop_y = [7.347,
7.93,
7.212,
7.13,
7.238

]
spark_y = [8.29,
0.704,
0.868,
0.583,
0.587

]


# Create the double bar graph
plt.bar(r1, hadoop_y, color='green', width=barWidth, label='Hadoop')
plt.bar(r2, spark_y, color='orange', width=barWidth, label='Spark')

# Add labels and title
plt.xlabel("Number of iterations")
plt.ylabel("Running Time (s)")
plt.title("Hadoop vs Spark for LateAircraft Delay")


# legend
plt.legend()

# Show the graph
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#Hadoop vs Spark for Security Delay



# Inserting inputs manually
x = ["1", "2", "3", "4", "5"]
hadoop_y = [7.656,
7.04,
7.839,
7.303,
6.942
]

spark_y = [8.538,
0.684,
0.726,
0.748,
0.765
]


# Create the double bar graph
plt.bar(r1, hadoop_y, color='green', width=barWidth, label='Hadoop')
plt.bar(r2, spark_y, color='orange', width=barWidth, label='Spark')

# Add labels and title
plt.xlabel("Number of iterations")
plt.ylabel("Running Time (s)")
plt.title("Hadoop vs Spark for Security Delay")


# legend
plt.legend()

# Show the graph
plt.show()
